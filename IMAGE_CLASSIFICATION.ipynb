# %% [markdown]
# <a href="https://colab.research.google.com/github/JOEPAULPPOULOSE/Cat-Dog_Image_CLass/blob/main/IMAGE_CLASSIFICATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import numpy as np
from sklearn.svm import SVC
from skimage.io import imread
from skimage.transform import resize
from sklearn.model_selection import train_test_split

# %%
os.listdir('/content/drive/MyDrive/IMAGE_DATA')
os.listdir('/content/drive/MyDrive/IMAGE_DATA/Cat')
# Out:
# ['cat.47.jpg',
#  'download7.jpeg',
#  'cat.53.jpg',
#  'cat.49.jpg',
#  'images.jpeg',
#  'cat.9.jpg',
#  'cat.5 - Copy.jpg',
#  'cat.32.jpg',
#  'cat.51.jpg',
#  'cat.7.jpg',
#  'download1.jpeg',
#  'cat.40.jpg',
#  'download5.jpeg',
#  'cat.43.jpg',
#  'download2.jpeg',
#  'cat.5.jpg',
#  'cat.41.jpg',
#  'images9.jpeg',
#  'download8.jpeg',
#  'cat.4 - Copy.jpg',
#  'download6.jpeg',
#  'download4.jpeg',
#  'cat.34.jpg',
#  'cat.16.jpg',
#  'cat.27.jpg',
#  'download.jpeg',
#  'cat.50.jpg',
#  'cat.21.jpg',
#  'cat.36.jpg',
#  'download3.jpeg',
#  'cat.35.jpg',
#  'cat.30.jpg',
#  'cat.28.jpg',
#  'cat.29.jpg',
#  'cat.52.jpg',
#  'cat.24.jpg',
#  'cat.38.jpg',
#  'cat.37.jpg',
#  'cat.15.jpg',
#  'cat.33.jpg',
#  'cat.8.jpg',
#  'cat.14.jpg',
#  'cat.17.jpg',
#  'cat.11.jpg',
#  'cat.12.jpg',
#  'cat.39.jpg',
#  'cat.2 - Copy.jpg',
#  'cat.46.jpg',
#  'cat.54.jpg',
#  'cat.1 - Copy.jpg',
#  'cat.44.jpg',
#  'cat.42.jpg',
#  'cat.18.jpg',
#  'cat.31.jpg',
#  'cat.3 - Copy.jpg',
# ...

# %%
os.listdir('/content/drive/MyDrive/IMAGE_DATA/Dog')
# Out:
# ['dog.42.jpg',
#  'dog.82.jpg',
#  'dog.61.jpg',
#  'dog.63.jpg',
#  'images.jpeg',
#  'download1.jpeg',
#  'download2.jpeg',
#  'dog.65.jpg',
#  'dog.56.jpg',
#  'dog.78.jpg',
#  'download4.jpeg',
#  'dog.81.jpg',
#  'download7.jpeg',
#  'dog.38.jpg',
#  'dog.45.jpg',
#  'download6.jpeg',
#  'dog.35.jpg',
#  'download8.jpeg',
#  'download5.jpeg',
#  'dog.60.jpg',
#  'download3.jpeg',
#  'dog.64.jpg',
#  'dog.57.jpg',
#  'dog.33.jpg',
#  'dog.67.jpg',
#  'dog.71.jpg',
#  'dog.34.jpg',
#  'dog.36.jpg',
#  'dog.40.jpg',
#  'dog.31.jpg',
#  'dog.46.jpg',
#  'dog.39.jpg',
#  'dog.77.jpg',
#  'dog.79.jpg',
#  'dog.51.jpg',
#  'images1.jpeg',
#  'dog.66.jpg',
#  'dog.70.jpg',
#  'dog.69.jpg',
#  'dog.80.jpg',
#  'dog.76.jpg',
#  'dog.68.jpg',
#  'dog.16.jpg',
#  'dog.19.jpg',
#  'dog.58.jpg',
#  'dog.14.jpg',
#  'dog.55.jpg',
#  'dog.21.jpg',
#  'dog.20.jpg',
#  'dog.15.jpg',
#  'dog.44.jpg',
#  'dog.27.jpg',
#  'dog.22.jpg',
#  'dog.48.jpg',
#  'dog.32.jpg',
#  'dog.24.jpg',
# ...

# %%
len(os.listdir('/content/drive/MyDrive/IMAGE_DATA/Cat'))
# Out:
# 60

# %%
len(os.listdir('/content/drive/MyDrive/IMAGE_DATA/Dog'))
# Out:
# 66

# %%
# datapath="/content/drive/MyDrive/IMAGE_DATA"
# sub_fol=os.listdir(datapath)
# print(sub_fol)

# for fol in sub_fol:
#   image_fol_path=os.path.join(datapath,fol)
#   #print(image_fol_path)
#   images=os.listdir(image_fol_path)
#   #print(images)

#   for img in images:
#     img_path=os.path.join(image_fol_path,img)
#     print(img_path)

# %%
data=[]
target=[]
categories=['Cat','Dog']
datadir='/content/drive/MyDrive/IMAGE_DATA'

# %%
for i in categories:
  print("Loading category images of ...",i)
  path=os.path.join(datadir,i)
  # print(path)
  images=os.listdir(path)
  # print(images)
  for img in images:
    img_path=os.path.join(path,img)
    img_array=imread(img_path)
    img_resize=resize(img_array,(180,180,3))
    data.append(img_resize.flatten())
    target.append(categories.index(i))

  print("category of ",i," loaded completely")
# Out:
# Loading category images of ... Cat
# category of  Cat  loaded completely
# Loading category images of ... Dog
# category of  Dog  loaded completely

# %%
 df=pd.DataFrame(data)
 df
# Out:
#         0         1         2         3         4         5         6      \
# 0    0.682193  0.527371  0.386442  0.715554  0.573808  0.455031  0.693150
# 1    0.506945  0.573612  0.369690  0.509832  0.576498  0.372577  0.515011
# 2    0.363862  0.310880  0.260863  0.328194  0.285393  0.242639  0.200724
# 3    0.565817  0.581503  0.577582  0.557974  0.573660  0.569739  0.542843
# 4    0.866667  0.937255  0.976471  0.869543  0.940131  0.979347  0.875362
# ..        ...       ...       ...       ...       ...       ...       ...
# 121  0.931968  0.931968  0.939811  0.936276  0.936276  0.944119  0.941590
# 122  0.324892  0.360187  0.379794  0.320538  0.355832  0.375440  0.317547
# 123  0.167084  0.096779  0.143437  0.126039  0.072567  0.119288  0.174438
# 124  0.627463  0.770446  0.754157  0.628029  0.765052  0.750099  0.635807
# 125  0.301943  0.556845  0.776453  0.301209  0.556111  0.775719  0.296713
#
#         7         8         9      ...     97190     97191     97192  \
# ...

# %%
df['target']=target
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.682193  0.527371  0.386442  0.715554  0.573808  0.455031  0.693150
# 1    0.506945  0.573612  0.369690  0.509832  0.576498  0.372577  0.515011
# 2    0.363862  0.310880  0.260863  0.328194  0.285393  0.242639  0.200724
# 3    0.565817  0.581503  0.577582  0.557974  0.573660  0.569739  0.542843
# 4    0.866667  0.937255  0.976471  0.869543  0.940131  0.979347  0.875362
# ..        ...       ...       ...       ...       ...       ...       ...
# 121  0.931968  0.931968  0.939811  0.936276  0.936276  0.944119  0.941590
# 122  0.324892  0.360187  0.379794  0.320538  0.355832  0.375440  0.317547
# 123  0.167084  0.096779  0.143437  0.126039  0.072567  0.119288  0.174438
# 124  0.627463  0.770446  0.754157  0.628029  0.765052  0.750099  0.635807
# 125  0.301943  0.556845  0.776453  0.301209  0.556111  0.775719  0.296713
#
#             7         8         9  ...     97191     97192     97193  \
# ...

# %%
X=np.array(data)
y=np.array(target)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(random_state=1)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay
print("***ACCURACY*** = ",accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
# ***ACCURACY*** =  55.26315789473685
#               precision    recall  f1-score   support
#
#            0       0.53      0.50      0.51        18
#            1       0.57      0.60      0.59        20
#
#     accuracy                           0.55        38
#    macro avg       0.55      0.55      0.55        38
# weighted avg       0.55      0.55      0.55        38
#
# ...

# %%
import matplotlib.pyplot as plt
new_image=imread("/content/drive/MyDrive/DOBERMAN.jpeg")
plt.imshow(new_image)

# %%
img=resize(new_image,(180,180,3)).flatten()
img=img.reshape(1,-1)
img.shape
# Out:
# (1, 97200)

# %%
y_new=rfc.predict(img)
if y_new==0:
  print("CAT")
else:
  print("DOG")
# Out:
# DOG

# %%
cat=imread("/content/drive/MyDrive/BLACK_CAT.jpeg")
plt.imshow(cat)
cat_img=resize(cat,(180,180,3)).flatten()
cimg=cat_img.reshape(1,-1)
cimg.shape
# Out:
# (1, 97200)

# %%
y_new=rfc.predict(cimg)
if y_new==0:
  print("CAT")
else:
  print("DOG")
# Out:
# CAT
